# %% [markdown]
# <a href="https://colab.research.google.com/github/SofiaAkhtar/Hang-Man-Game/blob/main/Hang_Man.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

def choose_word():
    words = ["python", "hangman", "programming", "computer", "science", "keyboard"]
    return random.choice(words)

def display_word(word, guessed_letters):
    display = ""
    for letter in word:
        if letter in guessed_letters:
            display += letter + " "
        else:
            display += "_ "
    return display.strip()

def display_hangman(attempts):
    hangman_display = [
        """
         ------
         |    |
         |
         |
         |
         |
        ---
        """
        ,
        """
         ------
         |    |
         |    O
         |
         |
         |
        ---
        """
        ,
        """
         ------
         |    |
         |    O
         |    |
         |
         |
        ---
        """
        ,
        """
         ------
         |    |
         |    O
         |   /|
         |
         |
        ---
        """
        ,
        """
         ------
         |    |
         |    O
         |   /|\\
         |
         |
        ---
        """
        ,
        """
         ------
         |    |
         |    O
         |   /|\\
         |   /
         |
        ---
        """
        ,
        """
         ------
         |    |
         |    O
         |   /|\\
         |   / \\
         |
        ---
        """
    ]
    print(hangman_display[attempts])

def hangman():
    print("Welcome to Hangman!")
    secret_word = choose_word()
    guessed_letters = []
    incorrect_attempts = 0
    max_attempts = 6

    while incorrect_attempts < max_attempts:
        print("\nAttempts left:", max_attempts - incorrect_attempts)
        print(display_word(secret_word, guessed_letters))
        display_hangman(incorrect_attempts)

        guess = input("Enter a letter: ").lower()

        if len(guess) != 1 or not guess.isalpha():
            print("Invalid input. Please enter a single letter.")
            continue

        if guess in guessed_letters:
            print("You've already guessed that letter. Try again.")
            continue

        guessed_letters.append(guess)

        if guess not in secret_word:
            incorrect_attempts += 1
            print("Incorrect guess. Try again.")

        if all(letter in guessed_letters for letter in secret_word):
            print("Congratulations! You guessed the word:", secret_word)
            break

    if incorrect_attempts == max_attempts:
        print("Sorry, you ran out of attempts. The correct word was:", secret_word)

# Run the game
hangman()
# Out:
# Welcome to Hangman!
#
# Attempts left: 6
# _ _ _ _ _ _ _ _ _ _ _
#
#          ------
#          |    |
#          |
#          |
#          |
#          |
#         ---
#
# Enter a letter: s
# Incorrect guess. Try again.
#
# Attempts left: 5
# _ _ _ _ _ _ _ _ _ _ _
#
#          ------
#          |    |
#          |    O
#          |
#          |
#          |
#         ---
#
# Enter a letter: h
# Incorrect guess. Try again.
#
# Attempts left: 4
# _ _ _ _ _ _ _ _ _ _ _
#
#          ------
#          |    |
#          |    O
#          |    |
#          |
#          |
#         ---
#
# Enter a letter: e
# Incorrect guess. Try again.
#
# Attempts left: 3
# _ _ _ _ _ _ _ _ _ _ _
#
#          ------
#          |    |
#          |    O
#          |   /|
#          |
#          |
#         ---
#
# Enter a letter: a
#
# Attempts left: 3
# _ _ _ _ _ a _ _ _ _ _
#
#          ------
#          |    |
#          |    O
#          |   /|
#          |
#          |
#         ---
#
# ...
